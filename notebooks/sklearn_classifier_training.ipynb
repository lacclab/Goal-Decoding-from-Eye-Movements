# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from itertools import product
import json
from collections import defaultdict

# call ../src/FoldSplitter.py
import sys

sys.path.append("../src")

from FoldSplitter import FoldSplitter

from sklearn.neighbors import KNeighborsClassifier
from sklearn.dummy import DummyClassifier
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import NMF, PCA

# %% [markdown]
# ## Constants

# %%
DISTANCE_MATRIX_PATH = "../data/raw/distances_duration_norm.csv"
LABELS_PATH = "../data/raw/dis.csv"

VALIDATIONS_ORDER = ["new_item", "new_subject", "new_item_and_subject"]
FOLD_INDICES = [0, 2, 4, 6, 8]
NUM_FOLDS = 10
FOLD_SPLITTER = FoldSplitter(
    item_columns=["batch", "article_id"],
    subject_column="subject_id",
    groupby_columns=[],
    num_folds=NUM_FOLDS,
)

TARGET_COLUMN = "has_preview"
if TARGET_COLUMN == "has_preview":  # determine positive label
    POS_LABEL = "Hunting"
else:
    raise ValueError(f"Unsupported target column - {TARGET_COLUMN}")

SCORER = {
    "accuracy": lambda y, y_pred: np.mean(y == y_pred),
    "precision": lambda y, y_pred: np.sum((y == POS_LABEL) & (y_pred == POS_LABEL))
    / np.sum(y_pred == POS_LABEL),
    "recall": lambda y, y_pred: np.sum((y == POS_LABEL) & (y_pred == POS_LABEL))
    / np.sum(y == POS_LABEL),
}

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ### Load Data

# %%
def load_distance_matrix(path=DISTANCE_MATRIX_PATH):
    distances_duration_norm = pd.read_csv(path)
    return distances_duration_norm


def load_labels(path=LABELS_PATH):
    labels = pd.read_csv(path)
    return labels

# %% [markdown]
# ### Preprocess Data

# %%
def preprocess_labels(labels):
    labels[["batch", "article_id", "level", "paragraph_id"]] = labels[
        "unique_paragraph_id"
    ].str.split("_", expand=True)
    labels["unique_id"] = (
        labels["has_preview"]
        + "_"
        + labels["subject_id"]
        + "_"
        + labels["unique_paragraph_id"]
    )

    # remove unwanted rows and remember which rows were removed
    rows_removed = labels["reread"] == 1

    ## remove reread
    labels = labels[labels["reread"] == 0]

    # reset index
    labels = labels.reset_index(drop=True)

    return labels, rows_removed

# %%
def preprocess_distances(distances, labels, rows_removed):
    df = distances.copy()
    # remove 'Unnamed: 0' column
    df = df.drop(columns="Unnamed: 0")

    # remove rows and columns that were removed in the labels preprocessing
    index = df.index
    columns = df.columns
    assert len(index) == len(columns) == len(rows_removed), print(
        f"{len(index)}, {len(columns)}, {len(rows_removed)}"
    )

    df = df.loc[df.index[~rows_removed], df.columns[~rows_removed]]

    # set lables['unique_id'] as distances_duration_norm index and columns
    df = df.set_index(labels["unique_id"])

    df.columns = labels["unique_id"]

    return df

# %% [markdown]
# ### Side Functions

# %%
def element_wise_mean(list_of_lists):
    return [np.mean(x) for x in zip(*list_of_lists)]

# %%
def get_hyperparameters_combinations(
    hyperparameters: dict[str, list], filter_func=None
):
    """
    Get all possible hyperparameters combinations
    """
    keys = hyperparameters.keys()
    values = hyperparameters.values()

    ret = [defaultdict(lambda: None, dict(zip(keys, v))) for v in product(*values)]
    if filter_func is not None:
        ret = list(filter(filter_func, ret))

    return ret

# %%
def train_val_test_generator(labels, distances):
    for fold_index in FOLD_INDICES:
        train_keys, val_keys_list, test_keys_list = (
            FOLD_SPLITTER._train_val_test_splits(
                group_keys=labels, fold_index=fold_index
            )
        )

        # distances from train_keys to train_keys
        train_distances = distances.loc[train_keys.unique_id, train_keys.unique_id]

        # distances from val_keys to train_keys
        val_list_distances = [
            distances.loc[val_keys.unique_id, train_keys.unique_id]
            for val_keys in val_keys_list
        ]

        # distances from test_keys to train_keys
        test_list_distances = [
            distances.loc[test_keys.unique_id, train_keys.unique_id]
            for test_keys in test_keys_list
        ]

        yield (
            fold_index,
            train_distances,
            val_list_distances,
            test_list_distances,
            train_keys,
            val_keys_list,
            test_keys_list,
        )

# %%
def get_classifier(hyperparameters):
    """return none if hyperparameters are invalid"""
    if hyperparameters["classifier"] == "knn":
        if (
            hyperparameters["dim_reduction"] is not None
            and hyperparameters["metric"] == "precomputed"
        ):
            return None
        if (
            hyperparameters["dim_reduction"] is None
            and hyperparameters["metric"] != "precomputed"
        ):
            return None
        clf = make_pipeline(
            KNeighborsClassifier(
                n_neighbors=hyperparameters["n_neighbors"],
                weights=hyperparameters["weights"],
                metric=hyperparameters["metric"],
            )
        )
        ## add dimensionality reduction
        if hyperparameters["dim_reduction"] is None:
            pass
        elif hyperparameters["dim_reduction"] == "pca":
            clf.steps.insert(
                0, ("pca", PCA(n_components=hyperparameters["n_components"]))
            )
        elif hyperparameters["dim_reduction"] == "nmf":
            clf.steps.insert(
                0, ("nmf", NMF(n_components=hyperparameters["n_components"]))
            )
        else:
            raise ValueError(
                f"Unsupported dimensionality reduction - {hyperparameters['dim_reduction']}"
            )

        return clf

    elif hyperparameters["classifier"] == "dummy":
        return DummyClassifier(strategy=hyperparameters["strategy"])
    else:
        return None

# %% [markdown]
# ### Training

# %%
def _train_clf(
    clf,
    distances,
    labels,
    fold_index,
    train_distances,
    val_list_distances,
    test_list_distances,
    train_keys,
    val_keys_list,
    test_keys_list,
):
    labels_with_unique_id_as_index = labels.set_index("unique_id")

    clf.fit(
        train_distances,
        labels_with_unique_id_as_index.loc[train_distances.index, TARGET_COLUMN],
    )

    # predict val and test
    val_preds = [clf.predict(val_distances) for val_distances in val_list_distances]
    test_preds = [clf.predict(test_distances) for test_distances in test_list_distances]

    # calculate scores
    val_scores = {
        scorer_name: [
            scorer(
                labels_with_unique_id_as_index.loc[val_keys.unique_id, TARGET_COLUMN],
                val_pred,
            )
            for val_keys, val_pred in zip(val_keys_list, val_preds)
        ]
        for scorer_name, scorer in SCORER.items()
    }

    test_scores = {
        scorer_name: [
            scorer(
                labels_with_unique_id_as_index.loc[test_keys.unique_id, TARGET_COLUMN],
                test_pred,
            )
            for test_keys, test_pred in zip(test_keys_list, test_preds)
        ]
        for scorer_name, scorer in SCORER.items()
    }

    return val_scores, test_scores

# %%
def train_clf(hyperparameters, labels, distances):
    """
    @param hyperparameters: dict (name, values_list)
    """
    clfs = [
        get_classifier(hp) for hp in get_hyperparameters_combinations(hyperparameters)
    ]

    # filter None values
    clfs = [clf for clf in clfs if clf is not None]

    # print number of classifiers and hyperparameters
    for i, clf in enumerate(clfs):
        print(f"Classifier {i}: {clf}")

    scores = {}

    for (
        fold_index,
        train_distances,
        val_list_distances,
        test_list_distances,
        train_keys,
        val_keys_list,
        test_keys_list,
    ) in train_val_test_generator(labels, distances):
        for clf in (pbar := tqdm(clfs)):
            # update description of tqdm to str(clf)
            pbar.set_description(str(clf))

            # train and evaluate classifier
            val_scores, test_scores = _train_clf(
                clf,
                distances,
                labels,
                fold_index,
                train_distances,
                val_list_distances,
                test_list_distances,
                train_keys,
                val_keys_list,
                test_keys_list,
            )

            # save scores
            scores[fold_index] = scores.get(fold_index, {})  # default dict
            scores[fold_index][str(clf)] = {
                "val": val_scores,
                "test": test_scores,
            }

    return scores

# %%
def save_scores(scores, path):
    with open(path, "w") as f:
        json.dump(scores, f)

# %% [markdown]
# ### Interperate Scores

# %%
def interprate_scores(scores):
    # interpret results

    ## for each fold, get the test scores for the best hyperparameters
    ## where the best hyperparameters are the ones that maximize the average of the scores
    best_hyperparameters_per_fold = {}
    for fold_index in scores:
        best_hyperparameters_per_fold[fold_index] = max(
            scores[fold_index].items(),
            key=lambda x: np.mean(x[1]["val"]["accuracy"]),
        )

    ## get the average of the scores for the best hyperparameters for each fold and average over all folds
    val_scores = {
        scorer_name: element_wise_mean(
            [
                scores[fold_index][best_hyperparameters_per_fold[fold_index][0]]["val"][
                    scorer_name
                ]
                for fold_index in scores
            ]
        )
        for scorer_name in SCORER.keys()
    }
    test_scores = {
        scorer_name: element_wise_mean(
            [
                scores[fold_index][best_hyperparameters_per_fold[fold_index][0]][
                    "test"
                ][scorer_name]
                for fold_index in scores
            ]
        )
        for scorer_name in SCORER.keys()
    }

    return best_hyperparameters_per_fold, val_scores, test_scores

# %%
def print_inter_scores_pretty(pretext, scores):
    print(pretext)
    """
    scores is a dict with the following structure:
    {
        scorer_name: [score_new-item, score_new-subject, score_new-item-and-subject]
    }
    print it as a table where columns are the val_order and rows are the scorer_name
    """
    df = pd.DataFrame(scores)

    # transpose
    df = df.T

    df.index = scores.keys()
    df.columns = VALIDATIONS_ORDER
    print(df, end="\n\n")

# %% [markdown]
# ## Training

# %%
print("Loading labels and distances...")
distances = load_distance_matrix()

# %% [markdown]
# ### kNN

# %%
print("Preprocessing labels and distances...")
labels = load_labels()
labels, rows_removed = preprocess_labels(labels)
processed_distances = preprocess_distances(distances, labels, rows_removed)

FOLD_SPLITTER.create_folds(group_keys=labels)

# train kNN classifier
hyperparameters = {
    "n_neighbors": [1, 2, 3, 5, 7, 9],
    "weights": ["uniform", "distance"],
    "metric": ["l2", "precomputed"],
    "classifier": ["knn"],
    "dim_reduction": [None, "pca", "nmf"],
    "n_components": [0.1, 0.3, 0.5, 0.7, 0.9],
}

print("Training classifiers...")
scores = train_clf(hyperparameters, labels, processed_distances)
# Out:
# HydraConfig not found. Using default path.
# ../data/folds
# Classifier 0: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1))])
# Classifier 1: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1))])
# Classifier 2: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1))])
# Classifier 3: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1))])
# Classifier 4: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1))])
# Classifier 5: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1))])
# Classifier 6: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1))])
# Classifier 7: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1))])
# Classifier 8: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1))])
# Classifier 9: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1))])
# Classifier 10: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1))])
# Classifier 11: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1))])
# Classifier 12: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1))])
# Classifier 13: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1))])
# Classifier 14: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1))])
# Classifier 15: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1))])
# Classifier 16: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1))])
# Classifier 17: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1))])
# Classifier 18: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1))])
# Classifier 19: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1))])
# Classifier 20: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=1))])
# Classifier 21: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=1))])
# Classifier 22: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=1))])
# Classifier 23: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=1))])
# Classifier 24: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=1))])
# Classifier 25: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 26: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 27: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 28: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 29: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 30: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 31: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 32: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 33: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 34: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 35: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 36: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 37: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 38: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 39: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 40: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 41: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 42: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 43: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 44: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 45: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 46: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 47: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 48: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 49: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=1,
#                                       weights='distance'))])
# Classifier 50: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2))])
# Classifier 51: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2))])
# Classifier 52: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2))])
# Classifier 53: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2))])
# Classifier 54: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2))])
# Classifier 55: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2))])
# Classifier 56: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2))])
# Classifier 57: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2))])
# Classifier 58: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2))])
# Classifier 59: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2))])
# Classifier 60: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2))])
# Classifier 61: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2))])
# Classifier 62: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2))])
# Classifier 63: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2))])
# Classifier 64: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2))])
# Classifier 65: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2))])
# Classifier 66: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2))])
# Classifier 67: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2))])
# Classifier 68: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2))])
# Classifier 69: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2))])
# Classifier 70: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=2))])
# Classifier 71: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=2))])
# Classifier 72: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=2))])
# Classifier 73: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=2))])
# Classifier 74: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=2))])
# Classifier 75: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 76: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 77: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 78: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 79: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 80: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 81: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 82: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 83: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 84: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 85: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 86: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 87: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 88: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 89: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 90: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 91: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 92: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 93: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 94: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 95: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 96: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 97: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 98: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 99: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=2,
#                                       weights='distance'))])
# Classifier 100: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3))])
# Classifier 101: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3))])
# Classifier 102: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3))])
# Classifier 103: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3))])
# Classifier 104: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3))])
# Classifier 105: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3))])
# Classifier 106: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3))])
# Classifier 107: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3))])
# Classifier 108: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3))])
# Classifier 109: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3))])
# Classifier 110: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3))])
# Classifier 111: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3))])
# Classifier 112: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3))])
# Classifier 113: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3))])
# Classifier 114: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3))])
# Classifier 115: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3))])
# Classifier 116: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3))])
# Classifier 117: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3))])
# Classifier 118: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3))])
# Classifier 119: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3))])
# Classifier 120: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=3))])
# Classifier 121: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=3))])
# Classifier 122: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=3))])
# Classifier 123: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=3))])
# Classifier 124: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=3))])
# Classifier 125: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 126: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 127: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 128: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 129: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 130: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 131: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 132: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 133: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 134: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 135: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 136: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 137: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 138: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 139: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 140: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 141: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 142: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 143: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 144: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 145: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 146: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 147: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 148: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 149: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=3,
#                                       weights='distance'))])
# Classifier 150: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l1'))])
# Classifier 151: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l1'))])
# Classifier 152: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l1'))])
# Classifier 153: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l1'))])
# Classifier 154: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l1'))])
# Classifier 155: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l1'))])
# Classifier 156: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l1'))])
# Classifier 157: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l1'))])
# Classifier 158: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l1'))])
# Classifier 159: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l1'))])
# Classifier 160: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l2'))])
# Classifier 161: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l2'))])
# Classifier 162: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l2'))])
# Classifier 163: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l2'))])
# Classifier 164: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l2'))])
# Classifier 165: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l2'))])
# Classifier 166: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l2'))])
# Classifier 167: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l2'))])
# Classifier 168: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l2'))])
# Classifier 169: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier', KNeighborsClassifier(metric='l2'))])
# Classifier 170: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed'))])
# Classifier 171: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed'))])
# Classifier 172: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed'))])
# Classifier 173: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed'))])
# Classifier 174: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed'))])
# Classifier 175: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', weights='distance'))])
# Classifier 176: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', weights='distance'))])
# Classifier 177: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', weights='distance'))])
# Classifier 178: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', weights='distance'))])
# Classifier 179: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', weights='distance'))])
# Classifier 180: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', weights='distance'))])
# Classifier 181: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', weights='distance'))])
# Classifier 182: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', weights='distance'))])
# Classifier 183: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', weights='distance'))])
# Classifier 184: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', weights='distance'))])
# Classifier 185: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', weights='distance'))])
# Classifier 186: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', weights='distance'))])
# Classifier 187: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', weights='distance'))])
# Classifier 188: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', weights='distance'))])
# Classifier 189: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', weights='distance'))])
# Classifier 190: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', weights='distance'))])
# Classifier 191: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', weights='distance'))])
# Classifier 192: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', weights='distance'))])
# Classifier 193: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', weights='distance'))])
# Classifier 194: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', weights='distance'))])
# Classifier 195: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed',
#                                       weights='distance'))])
# Classifier 196: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed',
#                                       weights='distance'))])
# Classifier 197: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed',
#                                       weights='distance'))])
# Classifier 198: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed',
#                                       weights='distance'))])
# Classifier 199: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed',
#                                       weights='distance'))])
# Classifier 200: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7))])
# Classifier 201: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7))])
# Classifier 202: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7))])
# Classifier 203: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7))])
# Classifier 204: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7))])
# Classifier 205: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7))])
# Classifier 206: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7))])
# Classifier 207: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7))])
# Classifier 208: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7))])
# Classifier 209: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7))])
# Classifier 210: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7))])
# Classifier 211: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7))])
# Classifier 212: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7))])
# Classifier 213: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7))])
# Classifier 214: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7))])
# Classifier 215: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7))])
# Classifier 216: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7))])
# Classifier 217: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7))])
# Classifier 218: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7))])
# Classifier 219: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7))])
# Classifier 220: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=7))])
# Classifier 221: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=7))])
# Classifier 222: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=7))])
# Classifier 223: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=7))])
# Classifier 224: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=7))])
# Classifier 225: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 226: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 227: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 228: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 229: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 230: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 231: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 232: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 233: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 234: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 235: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 236: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 237: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 238: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 239: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 240: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 241: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 242: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 243: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 244: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 245: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 246: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 247: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 248: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 249: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=7,
#                                       weights='distance'))])
# Classifier 250: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9))])
# Classifier 251: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9))])
# Classifier 252: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9))])
# Classifier 253: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9))])
# Classifier 254: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9))])
# Classifier 255: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9))])
# Classifier 256: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9))])
# Classifier 257: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9))])
# Classifier 258: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9))])
# Classifier 259: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9))])
# Classifier 260: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9))])
# Classifier 261: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9))])
# Classifier 262: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9))])
# Classifier 263: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9))])
# Classifier 264: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9))])
# Classifier 265: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9))])
# Classifier 266: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9))])
# Classifier 267: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9))])
# Classifier 268: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9))])
# Classifier 269: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9))])
# Classifier 270: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=9))])
# Classifier 271: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=9))])
# Classifier 272: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=9))])
# Classifier 273: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=9))])
# Classifier 274: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=9))])
# Classifier 275: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 276: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 277: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 278: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 279: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 280: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 281: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 282: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 283: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 284: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l1', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 285: Pipeline(steps=[('pca', PCA(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 286: Pipeline(steps=[('pca', PCA(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 287: Pipeline(steps=[('pca', PCA(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 288: Pipeline(steps=[('pca', PCA(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 289: Pipeline(steps=[('pca', PCA(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 290: Pipeline(steps=[('nmf', NMF(n_components=0.1)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 291: Pipeline(steps=[('nmf', NMF(n_components=0.3)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 292: Pipeline(steps=[('nmf', NMF(n_components=0.5)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 293: Pipeline(steps=[('nmf', NMF(n_components=0.7)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 294: Pipeline(steps=[('nmf', NMF(n_components=0.9)),
#                 ('kneighborsclassifier',
#                  KNeighborsClassifier(metric='l2', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 295: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 296: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 297: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 298: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=9,
#                                       weights='distance'))])
# Classifier 299: Pipeline(steps=[('kneighborsclassifier',
#                  KNeighborsClassifier(metric='precomputed', n_neighbors=9,
#                                       weights='distance'))])
# Test folds: [0, 1],             Validation fold: [2],             Train folds: [3, 4, 5, 6, 7, 8, 9]
# Train: # Trials: 8650. # Items: 206; # Subjects: 252
# Val seen_subject_unseen_item: # Trials: 1512. # Items: 36; # Subjects: 252
# Val unseen_subject_seen_item: # Trials: 1236. # Items: 206; # Subjects: 36
# Val unseen_subject_unseen_item: # Trials: 216. # Items: 36; # Subjects: 36
# Test seen_subject_unseen_item: # Trials: 3936. # Items: 82; # Subjects: 288
# Test unseen_subject_seen_item: # Trials: 2904. # Items: 242; # Subjects: 72
# Test unseen_subject_unseen_item: # Trials: 984. # Items: 82; # Subjects: 72
# All: # Trials: 19438. # Items: 324; # Subjects: 360
#   0%|          | 0/300 [00:00<?, ?it/s]

# %%
# save scores
save_scores(scores, "scores.json")

# interpret results
best_hyperparameters_per_fold, val_scores, test_scores = interprate_scores(scores)

# print results
print_inter_scores_pretty("Validation scores:", val_scores)
print_inter_scores_pretty("Test scores:", test_scores)
print(best_hyperparameters_per_fold)
